# %% [markdown]
# Day 7

# %% [markdown]
# str is iterable, mutable.

# %%
print('a', 'b', 'c', sep=(' then '))
# Out:
# a then b then c

# %%
"{!s}".format("hello") # do not use this too old fashion

"{0} {1} {name}".format("one", "two", name="North")
# 0 and 1 is the index

"%s, %s, %s, how are you?" % ("hello", "sally", "vetit") # similar to C/C++
# Out:
# 'hello, sally, vetit, how are you?'
